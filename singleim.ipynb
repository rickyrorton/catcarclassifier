# %%
from tensorflow.keras.models import load_model
import numpy as np
import os
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
model=load_model(os.path.join('models','catdogclassifier.h5'))
imsize=(128,128)

# %%
file='datasetbkup/test/cats/cat_56.jpg'
img=image.load_img(file, target_size=imsize)
resized_img=image.img_to_array(img)
final=np.expand_dims(resized_img,axis=0)
predictions=model.predict(final)
print('Confidence levels: \nCat: {}% \nCar: {}%'.format(str(predictions[0][1]*100),str(predictions[0][0]*100)))

img = mpimg.imread(file)
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 14ms/step
# Confidence levels:
# Cat: 99.78317618370056%
# Car: 0.21682274527847767%

# %%
file='datasetbkup/test/cars/253.jpg'
img=image.load_img(file, target_size=imsize)
resized_img=image.img_to_array(img)
final=np.expand_dims(resized_img,axis=0)
predictions=model.predict(final)
print('Confidence levels: \nCat: {}% \nCar: {}%'.format(str(predictions[0][1]*100),str(predictions[0][0]*100)))

img = mpimg.imread(file)
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 14ms/step
# Confidence levels:
# Cat: 0.18541630124673247%
# Car: 99.81458187103271%
